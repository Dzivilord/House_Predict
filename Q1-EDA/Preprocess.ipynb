# %% [markdown]
# <center>
#     <span style="color: #2E86C1; font-size: 3em;">
#         &#128202; Preprocessing Data
#     </span>
# </center>

# %% [markdown]
# # Nội dung Notebook

# %% [markdown]
# Notebook này tập trung cung vào việc xử lý dữ liệu đã được EDA để trích xuất ra bộ dữ liệu ổn định về phương diện chất lượng và số lượng cho việc huấn luyện mô hình tiếp theo

# %% [markdown]
# # Thư viện hỗ trợ.

# %% [markdown]
# ## Cài đặt thư viện hỗ trợ.

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install gdown
# !pip install scikit-learn
# !pip install kneed
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.7.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: kneed in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from kneed) (2.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from kneed) (1.15.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import gdown
import os
from google.colab import files

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, FunctionTransformer
from kneed import KneeLocator

# %% [markdown]
# # Tổng quan notebook
#
# | Tên đặc trưng         | Nội dung tiền xử lý                                                  |
# |-----------------------|----------------------------------------------------------------------|
# | **id**                | Loại bỏ                                                               |
# | **sale_date**         | Phân tách date &rarr; year, month, day                            |
# | **sale_price**        | Giữ không đổi                                                              |
# | **sale_nbr**          | Điền giá trị khuyết bằng median của train                            |
# | **sale_warning**      | Loại bỏ                                               |
# | **join_status**       | Gom nhóm đặc trưng- Chuyển thành category                                          |
# | **join_year**         | Loại bỏ                       |
# | **latitude**          | Dùng để tạo đặc trưng mới |
# | **longitude**         | Dùng để tạo đặc trưng mới |
# | **area**              | Gộp nhóm hiếm: giữ lại top 20 khu vực phổ biến, phần còn lại gán -1 --> area_mod|
# | **city**              | Loại bỏ |
# | **zoning**            | Dùng để tạo đặc trưng mới |
# | **subdivision**       | Loại bỏ |
# | **present_use**       | Tạo is_residential = (present_use == 2) --> loại present_use|
# | **land_val**          | Dùng để tạo đặc trưng mới |
# | **imp_val**           | Giữ không đổi |
# | **year_built**        | Giữ không đổi                                                    |
# | **year_reno**         | 0 --> NaN --> tạo has_reno, điền bằng year_built                        |
# | **sqft_lot**          | Giữ không đổi |
# | **sqft**              | Log-transform --> log_sqft, rồi loại bỏ sqft|
# | **sqft_1**            | Log-transform --> log_sqft_1, rồi loại bỏ sqft_1|
# | **sqft_fbsmt**        | Tạo has_basement, log-transform --> log_sqft_fbsmt, rồi loại bỏ sqft_fbsmt|
# | **grade**             | Giữ không đổi                                           |
# | **fbsmt_grade**       | Giữ không đổi                                           |
# | **condition**         | Giữ không đổi                    |
# | **stories**           | Giữ không đổi                                                             |
# | **beds**              | Giữ không đổi                                                            |
# | **bath_full**         | Giữ không đổi và tạo đặc trưng mới                                                   |
# | **bath_3qtr**         | Giữ không đổi và tạo đặc trưng mới                                                     |
# | **bath_half**         | Giữ không đổi và tạo đặc trưng mới                                                     |
# | **garb_sqft**         | Ép sang float64 và giới hạn trên cho miền giá trị                                                 |
# | **gara_sqft**         | Ép sang float64                                                       |
# | **wfnt**              | Chuyển về hai giá trị là `0` và `1`                                                  |
# | **golf**              | Giữ không đổi                                                  |
# | **greenbelt**         | Giữ không đổi                   |
# | **noise_traffic**     | Giữ không đổi          |
# | **view_rainier**      | Giữ không đổi                           |
# | **view_olympics**     | Tạo đặc trưng mới và tiến hành loại bỏ                            |
# | **view_cascades**     | Tạo đặc trưng mới và tiến hành loại bỏ                      |
# | **view_territorial**  | Tạo đặc trưng mới và tiến hành loại bỏ           |
# | **view_skyline**      | Giữ không đổi                   |
# | **view_sound**        |Tạo đặc trưng mới và tiến hành loại bỏ|
# | **view_lakewash**     |Tạo đặc trưng mới và tiến hành loại bỏ|
# | **view_lakesamm**     |Giữ không đổi|
# | **view_otherwater**   |Giữ không đổi|
# | **view_other**        |Giữ không đổi|
# | **submarket**         |Giữ không đổi|

# %% [markdown]
# | New features         | Mô tả                                                  |
# |-----------------------|----------------------------------------------------------------------|
# | **new_features_1**      | Đặc trưng mới được tạo từ tổng diện tích sàn và diện tích tầng hầm                |
# | **new_features_2**      | Đặc trưng phân loại theo nhóm giá trị sale_price (low, medium, high)              |
# | **new_features_3**      | Đặc trưng tương tác giữa số phòng ngủ và phòng tắm                                |
# | **new_features_4**      | Đặc trưng xác định bất động sản có tầm nhìn đặc biệt (tổng hợp các view_*)        |
# | **new_features_5**      | Đặc trưng tỷ lệ diện tích xây dựng trên diện tích đất (sqft / sqft_lot)           |
# | **val_per_sqft**        | Đặc trưng giá trị đất trên $m^2$                                                  |
# | **hotzone_cluster**     | Đặc trưng các nhà có vị trí địa lý nằm ở các vùng có giá trị đất trên $m^2$ khác nhau tương đối rõ ràng |
# | **zoning_cluster**      | Đặc trưng các nhà có zoning phân biệt rõ ràng dựa trên giá đất trên $m^2$ |
# | **total_bath**          | Đặc trưng tổng số phòng tắm (bath_full + 0.75 x bath_3qtr + 0.5 x bath_half)|
# | **view_west_combo** | Đặc trưng cảnh quang hướng Tây/Tây Bắc (view_olympics + view_sound + view_territorial)
# | **view_west_combo** | Đặc trưng cảnh quang hướng Đông/Đông Bắc (view_cascades + view_lakewash)
# | **log_sqft**            | Log-transform tổng diện tích xây dựng để giảm skewness                          |
# | **log_sqft_1**          | Log-transform diện tích tầng 1                                                   |
# | **log_sqft_fbsmt**      | Log-transform diện tích tầng hầm                                                |
# | **has_basement**        | Biến nhị phân: 1 nếu có tầng hầm, 0 nếu không                                   |
# | **has_reno**            | Biến nhị phân: 1 nếu nhà đã cải tạo, 0 nếu chưa                                 |
# | **is_residential**      | Biến nhị phân: 1 nếu `present_use == 2`, tức là nhà ở                           |
# | **area_mod**            | Gộp nhóm khu vực hiếm thành `-1`, giữ lại top 20 khu vực phổ biến              |

# %% [markdown]
# ## Đọc dữ liệu

# %%
dataset_dir = "/content/Dataset"
os.makedirs(dataset_dir, exist_ok=True)

# %%
data_folder='/content/Dataset/'

# %%
data_id = "1FI9O6U_MEKdpnYEFvwm_3D6j7GxPecNa"
test_id = "12wBX-Q6cH8Th8HOwezJa1LZT5aiglIpK"
gdown.download(f"https://drive.google.com/uc?id={data_id}", data_folder + "dataset.csv", quiet=False)
gdown.download(f"https://drive.google.com/uc?id={test_id}", data_folder + "test.csv", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FI9O6U_MEKdpnYEFvwm_3D6j7GxPecNa
# To: /content/Dataset/dataset.csv
# 100%|██████████| 38.4M/38.4M [00:00<00:00, 152MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12wBX-Q6cH8Th8HOwezJa1LZT5aiglIpK
# To: /content/Dataset/test.csv
# 100%|██████████| 37.1M/37.1M [00:00<00:00, 107MB/s]
# '/content/Dataset/test.csv'

# %%
data = pd.read_csv(data_folder + 'dataset.csv')
test_data = pd.read_csv(data_folder + 'test.csv')

# %%
train_data = data.drop('id', axis = 1)

# %% [markdown]
# # I. Nhóm đặc trưng về giao dịch mua bán

# %% [markdown]
# ## Tiền xử lý sale_date

# %% [markdown]
# Đưa dữ liệu ngày tháng thành giá trị số liên tục nhằm biến đổi thành đặc trưng có thể sử dụng cho huấn luyện mô hình, dữ liệu được chuyển đổi thành khoảng cách so với 1 mốc thời gian.

# %%
invalid__train_dates = train_data['sale_date'][~train_data['sale_date'].astype(str).str.match(r'^\d{4}-\d{2}-\d{2}$')]
print("Invalid train__sale_date formats:", invalid__train_dates.unique())
# Out:
# Invalid train__sale_date formats: []

# %%
invalid_dates_test = test_data['sale_date'][~test_data['sale_date'].astype(str).str.match(r'^\d{4}-\d{2}-\d{2}$')]
print("Invalid test__sale_date formats:", invalid_dates_test.unique())
# Out:
# Invalid test__sale_date formats: []

# %%
train_data['sale_date'] = pd.to_datetime(train_data['sale_date'], errors='coerce')
train_data['sale_year'] = train_data['sale_date'].dt.year
train_data['sale_month'] = train_data['sale_date'].dt.month
train_data['sale_day'] = train_data['sale_date'].dt.day
train_data = train_data.drop('sale_date', axis=1)

# %%
test_data['sale_date'] = pd.to_datetime(test_data['sale_date'], errors='coerce')
test_data['sale_year'] = test_data['sale_date'].dt.year
test_data['sale_month'] = test_data['sale_date'].dt.month
test_data['sale_day'] = test_data['sale_date'].dt.day
test_data.drop('sale_date', axis=1, inplace=True)

# %% [markdown]
# ## Tiền xử lý sale_price: Giữ không xoá bỏ outlier

# %% [markdown]
# ## Tiền xử lý sale_nbr

# %%
print(train_data['sale_nbr'].isnull().sum())
# Out:
# 42182

# %%
print(test_data['sale_nbr'].isnull().sum())
# Out:
# 42412

# %%
sale_nbr_meadian=train_data['sale_nbr'].median()
train_data.loc[:, 'sale_nbr'] = train_data['sale_nbr'].fillna(sale_nbr_meadian)
test_data.loc[:, 'sale_nbr'] = test_data['sale_nbr'].fillna(sale_nbr_meadian)

# %% [markdown]
# ## Tiền xử lý sale_warning

# %% [markdown]
# 90% đặc trưng này chung một giá trị, 10% còn lại được phân bố cho hơn 140 giá trị categorical khác nhau đồng thời ít tương quan với thuộc tính nhãn nên xoá đi

# %%
train_data=train_data.drop(columns=['sale_warning'])
test_data=test_data.drop(columns=['sale_warning'])

# %% [markdown]
# ## Tiền xử lý join_status

# %%
train_data['join_status'].value_counts()
# Out:
# join_status
# nochg               126281
# new                  53085
# reno - before         5864
# rebuilt - before      3706
# rebuilt - after       3095
# demo                  2869
# reno - after          2632
# miss99                2468
# Name: count, dtype: int64

# %%
test_data['join_status'].value_counts()
# Out:
# join_status
# nochg               126519
# new                  52648
# reno - before         6001
# rebuilt - before      3568
# rebuilt - after       3146
# demo                  2866
# reno - after          2654
# miss99                2598
# Name: count, dtype: int64

# %%
train_data['join_status'] = train_data['join_status'].replace(
    ['miss99', 'demo', 'rebuilt - after', 'reno - after'], 'nochg'
).astype('category')
test_data['join_status'] = test_data['join_status'].replace(
    ['miss99', 'demo', 'rebuilt - after', 'reno - after'], 'nochg'
).astype('category')

# %% [markdown]
# ## Tiền xử lý join_year

# %% [markdown]
# Đặc trưng này thể hiện tương quan kém với nhãn mục tiêu, đồng thời nội dung có thể suy ra từ đặc trưng join_status

# %%
train_data=train_data.drop(columns=['join_year'])
test_data=test_data.drop(columns=['join_year'])

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 46 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sale_price        200000 non-null  int64
#  1   sale_nbr          200000 non-null  float64
#  2   join_status       200000 non-null  category
#  3   latitude          200000 non-null  float64
#  4   longitude         200000 non-null  float64
#  5   area              200000 non-null  int64
#  6   city              200000 non-null  object
#  7   zoning            200000 non-null  object
#  8   subdivision       182450 non-null  object
#  9   present_use       200000 non-null  int64
#  10  land_val          200000 non-null  int64
#  11  imp_val           200000 non-null  int64
#  12  year_built        200000 non-null  int64
#  13  year_reno         200000 non-null  int64
#  14  sqft_lot          200000 non-null  int64
#  15  sqft              200000 non-null  int64
#  16  sqft_1            200000 non-null  int64
#  17  sqft_fbsmt        200000 non-null  int64
#  18  grade             200000 non-null  int64
#  19  fbsmt_grade       200000 non-null  int64
#  20  condition         200000 non-null  int64
#  21  stories           200000 non-null  float64
#  22  beds              200000 non-null  int64
#  23  bath_full         200000 non-null  int64
#  24  bath_3qtr         200000 non-null  int64
#  25  bath_half         200000 non-null  int64
#  26  garb_sqft         200000 non-null  int64
#  27  gara_sqft         200000 non-null  int64
#  28  wfnt              200000 non-null  int64
#  29  golf              200000 non-null  int64
#  30  greenbelt         200000 non-null  int64
#  31  noise_traffic     200000 non-null  int64
#  32  view_rainier      200000 non-null  int64
#  33  view_olympics     200000 non-null  int64
#  34  view_cascades     200000 non-null  int64
#  35  view_territorial  200000 non-null  int64
#  36  view_skyline      200000 non-null  int64
#  37  view_sound        200000 non-null  int64
#  38  view_lakewash     200000 non-null  int64
#  39  view_lakesamm     200000 non-null  int64
#  40  view_otherwater   200000 non-null  int64
#  41  view_other        200000 non-null  int64
#  42  submarket         198283 non-null  object
#  43  sale_year         200000 non-null  int32
#  44  sale_month        200000 non-null  int32
#  45  sale_day          200000 non-null  int32
# dtypes: category(1), float64(4), int32(3), int64(34), object(4)
# memory usage: 66.6+ MB

# %% [markdown]
# # II. Nhóm đặc trưng địa lý

# %%
geography_feature = ['latitude', 'longitude', 'city', 'zoning', 'subdivision', 'land_val', 'imp_val', 'sqft_lot']

geography_data = train_data[geography_feature].copy()

geography_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   latitude     200000 non-null  float64
#  1   longitude    200000 non-null  float64
#  2   city         200000 non-null  object
#  3   zoning       200000 non-null  object
#  4   subdivision  182450 non-null  object
#  5   land_val     200000 non-null  int64
#  6   imp_val      200000 non-null  int64
#  7   sqft_lot     200000 non-null  int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 12.2+ MB

# %%
geography_data.describe()
# Out:
#             latitude      longitude      land_val       imp_val      sqft_lot
# count  200000.000000  200000.000000  2.000000e+05  2.000000e+05  2.000000e+05
# mean       47.549248    -122.210416  4.601691e+05  4.917715e+05  1.378310e+04
# std         0.142710       0.140339  3.510444e+05  3.680505e+05  3.793152e+04
# min        47.155200    -122.527700  0.000000e+00  0.000000e+00  3.750000e+02
# 25%        47.446500    -122.323800  2.310000e+05  2.800000e+05  5.000000e+03
# 50%        47.562800    -122.222700  3.770000e+05  4.090000e+05  7.438000e+03
# 75%        47.673500    -122.121700  5.940000e+05  5.990000e+05  1.022000e+04
# max        47.777800    -121.161300  1.386400e+07  1.006700e+07  2.310573e+06

# %%
geography_data["val_per_sqft"] = geography_data["land_val"] / geography_data["sqft_lot"]

# %% [markdown]
# ## 1. Feature Engineer - Tạo hotzone các vùng có giá trị đất trên $m^2$ cao.

# %% [markdown]
# - Đầu tiên ta sử dụng Elbow Method để tìm giá trị k phù hợp nhất để sử dụng cho phân cụm k-mean kế tiếp
#
# - Đồng thời ta cũng sử dụng KneeLocator để xác định chính xác elbow.

# %%
# Bước 1: Lấy dữ liệu và chuẩn hóa
valid_data = geography_data[["latitude", "longitude", "val_per_sqft"]].copy()
scaled_data = StandardScaler().fit_transform(valid_data)

# Bước 2: Elbow Method + tính WCSS
wcss = []
K = range(2, 30)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)

# Bước 3: Dùng KneeLocator để tìm elbow
hotzone_knee = KneeLocator(K, wcss, curve='convex', direction='decreasing')
print(f"Optimal cluster based on Elbow Method (KneeLocator): k = {hotzone_knee.knee}")

# Bước 4: Vẽ biểu đồ có đánh dấu điểm elbow
plt.figure(figsize=(10, 6))
plt.plot(K, wcss, marker='o')
plt.vlines(hotzone_knee.knee, plt.ylim()[0], plt.ylim()[1], linestyles="dashed", colors="red", label=f"Elbow at k = {hotzone_knee.knee}")
plt.title('Elbow Method for Hotzone Clustering (with KneeLocator)')
plt.xlabel('Cluster (k)')
plt.ylabel('WCSS (Inertia)')
plt.xticks(K)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Optimal cluster based on Elbow Method (KneeLocator): k = 9

# %% [markdown]
# - Dựa vào kết quả của đoạn mã trên, ta quyết định sử dụng k=9 cho việc phân cụm các hotzone.

# %%
# Bước 1: Chuẩn hóa dữ liệu đầu vào
hotzone_features = geography_data[["latitude", "longitude", "val_per_sqft"]].dropna()
scaler_hotzone = StandardScaler()
scaled_hotzone = scaler_hotzone.fit_transform(hotzone_features)

# Bước 2: Huấn luyện KMeans
kmeans_hotzone = KMeans(n_clusters=hotzone_knee.knee, random_state=42)
geography_data["hotzone_cluster"] = kmeans_hotzone.fit_predict(scaled_hotzone)

# --- Bước 6: Visualization ---
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=geography_data,
    x="longitude",
    y="latitude",
    hue="hotzone_cluster",
    palette="coolwarm",
    legend="full",
    alpha=0.7
)
plt.title("Hotzone Clustering by Value per m² (Ranked)")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(title="Hotzone Cluster")
plt.show()

# %% [markdown]
# ## 2. Feature Engineer - Gom các zoning lại thành các cụm có ý nghĩa.

# %%
geography_data['zoning'].unique().__len__()
# Out:
# 500

# %% [markdown]
# - Như ta đã thấy, có tới 500 giá trị khác nhau trong `zoning`, mà chúng còn là những chuỗi ký tự, thứ mà các model khó mà học hiệu quả được.
# - Do đó ta sẽ dựa vào giá trị đất trên $m^2$ trung của các zoning để chia chúng thành những cluster có ý nghĩa hơn.
# - Ta cũng sẽ làm tương tự như trên, sử dụng KneeLocator và Elbow Method để xác định số k phù hợp để phân cụm
# - Sử dụng k-mean cluster để phân cụm

# %%
# Tính median val_per_sqft theo zoning
zoning_val_df = geography_data.groupby("zoning")["val_per_sqft"].median().reset_index()
zoning_val_df.rename(columns={"val_per_sqft": "median_val_per_sqft"}, inplace=True)

# Chuẩn hóa
scaler = StandardScaler()
scaled_vals = scaler.fit_transform(zoning_val_df[["median_val_per_sqft"]])

# Elbow Method: tính WCSS
wcss = []
K_range = range(2, 30)
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_vals)
    wcss.append(kmeans.inertia_)

# Dùng KneeLocator để tìm điểm gãy
zoning_knee = KneeLocator(K_range, wcss, curve="convex", direction="decreasing")
print(f"Optimal cluster based on Elbow Method (KneeLocator): k = {zoning_knee.knee}")

# Vẽ biểu đồ Elbow có highlight điểm elbow
plt.figure(figsize=(10, 6))
plt.plot(K_range, wcss, marker='o')
plt.vlines(zoning_knee.knee, plt.ylim()[0], plt.ylim()[1], linestyles="dashed", colors="red", label=f"Elbow at k = {zoning_knee.knee}")
plt.title('Elbow Method with KneeLocator')
plt.xlabel('Cluster (k)')
plt.ylabel('WCSS (Inertia)')
plt.xticks(K)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Optimal cluster based on Elbow Method (KneeLocator): k = 7

# %% [markdown]
# - Dựa vào kết quả của đoạn mã trên, chúng ta sẽ sử dụng k=6 cho việc phân cụm kế tiếp.

# %%
# Tính median val_per_sqft theo zoning
zoning_val_df = geography_data.groupby("zoning")["val_per_sqft"].median().reset_index()
zoning_val_df.rename(columns={"val_per_sqft": "median_val_per_sqft"}, inplace=True)

# Chuẩn hóa và gom cụm zoning
scaler_zoning = StandardScaler()
scaled_zoning = scaler_zoning.fit_transform(zoning_val_df[["median_val_per_sqft"]])

kmeans_zoning = KMeans(n_clusters=zoning_knee.knee, random_state=42)
zoning_val_df["zoning_cluster"] = kmeans_zoning.fit_predict(scaled_zoning)

# Tạo mapping zoning → cluster
zoning_cluster_mapping = dict(zip(zoning_val_df["zoning"], zoning_val_df["zoning_cluster"]))

# Gán cluster vào train
geography_data["zoning_cluster"] = geography_data["zoning"].map(zoning_cluster_mapping)

plt.figure(figsize=(10, 6))
sns.boxplot(data=zoning_val_df, x="zoning_cluster", y="median_val_per_sqft")
plt.title("Cluster Zoning based on median val_per_sqft")
plt.xlabel("Zoning Cluster")
plt.ylabel("Median val_per_sqft")
plt.show()

# %%
geography_data
# Out:
#         latitude  longitude         city   zoning  \
# 0        47.2917  -122.3658  FEDERAL WAY    RS7.2
# 1        47.6531  -122.1996     KIRKLAND   RS 8.5
# 2        47.4733  -122.1901       RENTON      R-8
# 3        47.4739  -122.3295       BURIEN  RS-7200
# 4        47.7516  -122.1222  KING COUNTY    RA2.5
# ...          ...        ...          ...      ...
# 199995   47.5503  -122.0285     ISSAQUAH     SF-E
# 199996   47.6789  -122.1164      REDMOND      NMF
# 199997   47.6939  -122.3542      SEATTLE  LR3 (M)
# 199998   47.6433  -122.0613    SAMMAMISH       R4
# 199999   47.5806  -122.3881      SEATTLE  LR3 (M)
#
#                             subdivision  land_val  imp_val  sqft_lot  \
# 0            ALDERWOOD SOUTH DIV NO. 02    167000   372000     10919
# 1                  WILDWOOD LANE NO. 03   1184000   598000      8900
# 2            FALCON RIDGE (CEDAR RIDGE)    230000   356000      4953
# 3                   OLYMPIC VUE ESTATES    190000   518000      6799
# 4              HOLLYWOOD HILL HIGHLANDS    616000  1917000     31687
# ...                                 ...       ...      ...       ...
# 199995             OVERDALE PARK NO. 03    521000   620000     29250
# 199996                              C P    667000  1107000      7677
# 199997        OSNERS SUBURBAN HOMES ADD    225000   492000       808
# 199998                TIMBERLINE NO. 01    554000   617000     11712
# 199999  WEST SEATTLE L&I CO 4TH PLAT OF    268000   455000       642
#
#         val_per_sqft  hotzone_cluster  zoning_cluster
# 0          15.294441                4               3
# 1         133.033708                6               5
# 2          46.436503                0               1
# 3          27.945286                1               3
# 4          19.440149                3               3
# ...              ...              ...             ...
# 199995     17.811966                3               3
# 199996     86.882897                6               5
# 199997    278.465347                7               2
# 199998     47.301913                3               1
# 199999    417.445483                7               2
#
# [200000 rows x 11 columns]

# %% [markdown]
# - Áp dụng vào train_data

# %%
train_data = train_data.reset_index(drop=True)
geography_data = geography_data.reset_index(drop=True)

train_data["val_per_sqft"] = geography_data["val_per_sqft"]
train_data["hotzone_cluster"] = geography_data["hotzone_cluster"]
train_data["zoning_cluster"] = geography_data["zoning_cluster"]

# %% [markdown]
# - Áp dụng feature engineer cho test

# %%
# Tính val_per_sqft cẩn thận để tránh chia cho 0
test_data["val_per_sqft"] = test_data.apply(
    lambda row: row["land_val"] / row["sqft_lot"] if row["sqft_lot"] > 0 else 0,
    axis=1
)

# %%
test_hotzone_input = test_data[["latitude", "longitude", "val_per_sqft"]]
scaled_test = scaler_hotzone.transform(test_hotzone_input)

test_data["hotzone_cluster"] = kmeans_hotzone.predict(scaled_test)

# %%
# Gán zoning_cluster từ mapping đã học
test_data["zoning_cluster"] = test_data["zoning"].map(zoning_cluster_mapping)

# Nếu có zoning chưa từng gặp
test_data["zoning_cluster"] = test_data["zoning_cluster"].fillna(-1)

# %% [markdown]
# - Sau khi feature engineer, 3 đặc trưng mới này đã thể hiện đầy đủ ý nghĩa địa lý của dữ liệu. Do đó, ta sẽ xóa các đặc trưng địa lý.

# %%
drop_cols = ['latitude', 'longitude', 'zoning', 'land_val', 'city', 'subdivision']
train_data.drop(columns=drop_cols, inplace=True, errors='ignore')
test_data.drop(columns=drop_cols, inplace=True, errors='ignore')

# %% [markdown]
# # III. Các đặc trưng nhóm Diện tích - Tuổi nhà - Chất lượng

# %% [markdown]
# ## 1. Xử lý year_reno

# %%
for df in [train_data, test_data]:
    df['year_reno'] = df['year_reno'].replace(0, np.nan)
    df['has_reno'] = df['year_reno'].notna().astype(int)
    df['year_reno'] = df['year_reno'].fillna(df['year_built'])

# %% [markdown]
# ## 2. Xử lý sqft_fbsmt

# %%
# Tạo biến nhị phân thể hiện có tầng hầm hay không
for df in [train_data, test_data]:
    df['has_basement'] = (df['sqft_fbsmt'] > 0).astype(int)

# %% [markdown]
# ## 3. Xử lý present_use

# %%
# Tạo biến nhị phân residential vs. non-residential
# (theo EDA thì present_use == 2 là residential)
for df in [train_data, test_data]:
    df['is_residential'] = (df['present_use'] == 2).astype(int)

# %% [markdown]
# ## 4. Xử lý area (gộp nhóm hiếm)

# %%
# Giữ lại top 20 khu vực (theo tần suất), gộp còn lại vào "Other"
top_areas = train_data['area'].value_counts().nlargest(20).index
train_data['area_mod'] = train_data['area'].where(train_data['area'].isin(top_areas), other=-1).astype(str)
test_data['area_mod'] = test_data['area'].where(test_data['area'].isin(top_areas), other=-1).astype(str)

# %% [markdown]
# ## 5. Log-transform cho biến skewed

# %%
# Đóng gói hàm log1p
log1p = FunctionTransformer(np.log1p, validate=True)

log1p_sqft       = FunctionTransformer(np.log1p, validate=True)
log1p_sqft_1     = FunctionTransformer(np.log1p, validate=True)
log1p_fbsmt      = FunctionTransformer(np.log1p, validate=True)

train_data['log_sqft']       = log1p_sqft.fit_transform(train_data[['sqft']])
train_data['log_sqft_1']     = log1p_sqft_1.fit_transform(train_data[['sqft_1']])
train_data['log_sqft_fbsmt'] = log1p_fbsmt.fit_transform(train_data[['sqft_fbsmt']])

test_data['log_sqft']       = log1p_sqft.transform(test_data[['sqft']])
test_data['log_sqft_1']     = log1p_sqft_1.transform(test_data[['sqft_1']])
test_data['log_sqft_fbsmt'] = log1p_fbsmt.transform(test_data[['sqft_fbsmt']])

# %% [markdown]
# ## 6. Xóa cột dư thừa sau khi tiền xử lý

# %%
drop_cols = ['present_use', 'area', 'sqft', 'sqft_1', 'sqft_fbsmt']

train_data = train_data.drop(columns=drop_cols)
test_data  = test_data.drop(columns=drop_cols)

# %% [markdown]
# # IV. Nhóm đặc trưng về cấu trúc và số phòng:

# %%
struct_room_data= train_data[['condition','stories','beds','bath_full','bath_3qtr','bath_half']]
test_struct_room_data = test_data[['condition','stories','beds','bath_full','bath_3qtr','bath_half']]

# %% [markdown]
# ## 1. Giữ nguyên các đặc trưng.

# %% [markdown]
# ## 2. Tạo đặc trưng mới là `total_bath`. Có nghĩa là `tổng phòng tắm`

# %%
struct_room_data= struct_room_data.copy()
struct_room_data['total_bath'] = (struct_room_data['bath_full'] +
                                   0.75*struct_room_data['bath_3qtr'] +
                                      0.5*struct_room_data['bath_half'])

test_struct_room_data= test_struct_room_data.copy()
test_struct_room_data['total_bath'] = (test_struct_room_data['bath_full'] +
                                         0.75*test_struct_room_data['bath_3qtr'] +
                                            0.5*test_struct_room_data['bath_half'])

# %% [markdown]
# ## 3. Gán vô dữ liệu chính

# %%
# Gán vô bảng dữ liệu chính
train_data = pd.concat([train_data, struct_room_data['total_bath']], axis=1)
test_data = pd.concat([test_data, test_struct_room_data['total_bath']], axis=1)

train_data[['condition', 'stories', 'beds', 'bath_full', 'bath_3qtr', 'bath_half']]= struct_room_data[['condition', 'stories', 'beds', 'bath_full', 'bath_3qtr', 'bath_half']]
test_data[['condition', 'stories', 'beds', 'bath_full', 'bath_3qtr', 'bath_half']]= test_struct_room_data[['condition', 'stories', 'beds', 'bath_full', 'bath_3qtr', 'bath_half']]

# %% [markdown]
# # V. Nhóm các đặc trưng về gara và không gian phụ trợ

# %%
gara_room= train_data[['garb_sqft','gara_sqft']]
test_gara_room= test_data[['garb_sqft','gara_sqft']]

# %% [markdown]
# ## 1. Ép kiểu phù hợp cho đặc trưng `garb_sqft`, `gara_sqft`

# %%
gara_room= gara_room.copy()
gara_room['garb_sqft'] = gara_room['garb_sqft'].astype('float64')
gara_room['gara_sqft'] = gara_room['gara_sqft'].astype('float64')

test_gara_room= test_gara_room.copy()
test_gara_room['garb_sqft'] = test_gara_room['garb_sqft'].astype('float64')
test_gara_room['gara_sqft'] = test_gara_room['gara_sqft'].astype('float64')

# %% [markdown]
# ## 2. Đặc trưng `garb_sqft` ở dữ liệu train, giá trị max rất lớn so với dữ liệu test do đó ta sẽ giới hạn trên cho dữ liệu train.

# %%
gara_room=gara_room.copy()
gara_room['garb_sqft'] = gara_room['garb_sqft'].clip(upper=4000)

# %% [markdown]
# ## 3. Gán vô dữ liệu chính

# %%
train_data[['garb_sqft', 'gara_sqft']] = gara_room[['garb_sqft', 'gara_sqft']]
test_data[['garb_sqft', 'gara_sqft']] = test_gara_room[['garb_sqft', 'gara_sqft']]

# %% [markdown]
# # VI. Nhóm các đặc trưng về môi trường

# %%
env_data=train_data[['wfnt','golf','greenbelt','noise_traffic']]
test_env_data=test_data[['wfnt','golf','greenbelt','noise_traffic']]

# %% [markdown]
# ## 1. Các đặc trưng `golf`, `greenbelt`, `noise_traffic` sẽ giữ nguyên. Đặc trưng `wfnt` vì quá lệch dữ liệu về `0` nên sẽ chuyển về dạng nhị phân gồm `0` và `1`.

# %%
env_data= env_data.copy()
test_env_data= test_env_data.copy()
env_data['wfnt'] = env_data['wfnt'].apply(lambda x: 1 if x > 0 else 0)
test_env_data['wfnt'] = test_env_data['wfnt'].apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# ## 2. Gán vô dữ liệu chính

# %%
train_data[['wfnt', 'golf', 'greenbelt', 'noise_traffic']] = env_data[['wfnt', 'golf', 'greenbelt', 'noise_traffic']]
test_data[['wfnt', 'golf', 'greenbelt', 'noise_traffic']] = test_env_data[['wfnt', 'golf', 'greenbelt', 'noise_traffic']]

# %% [markdown]
# # VII. Nhóm các đặc trưng về cảnh quan

# %% [markdown]
# Dựa theo phân tích từ ma trận tương quan, ta sẽ tiến hành xử lý các đặc trưng có tương quan với nhau và tiến hành tạo thêm đặc trưng mới phù hợp hơn cho phần mô hình hóa dữ liệu

# %% [markdown]
# ##### Nhóm 1: View hướng Tây / Tây Bắc

# %%
train_data['view_west_combo'] = train_data[['view_olympics', 'view_sound', 'view_territorial']].sum(axis=1)

test_data['view_west_combo'] = test_data[['view_olympics', 'view_sound', 'view_territorial']].sum(axis=1)

# %% [markdown]
# ##### Nhóm 2: View hướng Đông / Đông Bắc

# %%
train_data['view_east_combo'] = train_data[['view_cascades', 'view_lakewash']].sum(axis=1)
test_data['view_east_combo'] = test_data[['view_cascades', 'view_lakewash']].sum(axis=1)

# %% [markdown]
# Sau khi đã thêm các đặc trưng mới, ta sẽ tiến hành loại bỏ các đặc trưng cũ.

# %%
train_data.drop(columns=[
    'view_olympics', 'view_sound', 'view_territorial',
    'view_cascades', 'view_lakewash'
], inplace=True)
test_data.drop(columns=[
    'view_olympics', 'view_sound', 'view_territorial',
    'view_cascades', 'view_lakewash'
], inplace=True)

# %% [markdown]
# # Lưu dữ liệu mới

# %%
train_data.shape
# Out:
# (200000, 43)

# %%
test_data.shape
# Out:
# (200000, 43)

# %%
train_data.columns
# Out:
# Index(['sale_price', 'sale_nbr', 'join_status', 'imp_val', 'year_built',
#        'year_reno', 'sqft_lot', 'grade', 'fbsmt_grade', 'condition', 'stories',
#        'beds', 'bath_full', 'bath_3qtr', 'bath_half', 'garb_sqft', 'gara_sqft',
#        'wfnt', 'golf', 'greenbelt', 'noise_traffic', 'view_rainier',
#        'view_skyline', 'view_lakesamm', 'view_otherwater', 'view_other',
#        'submarket', 'sale_year', 'sale_month', 'sale_day', 'val_per_sqft',
#        'hotzone_cluster', 'zoning_cluster', 'has_reno', 'has_basement',
#        'is_residential', 'area_mod', 'log_sqft', 'log_sqft_1',
#        'log_sqft_fbsmt', 'total_bath', 'view_west_combo', 'view_east_combo'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['id', 'sale_nbr', 'join_status', 'imp_val', 'year_built', 'year_reno',
#        'sqft_lot', 'grade', 'fbsmt_grade', 'condition', 'stories', 'beds',
#        'bath_full', 'bath_3qtr', 'bath_half', 'garb_sqft', 'gara_sqft', 'wfnt',
#        'golf', 'greenbelt', 'noise_traffic', 'view_rainier', 'view_skyline',
#        'view_lakesamm', 'view_otherwater', 'view_other', 'submarket',
#        'sale_year', 'sale_month', 'sale_day', 'val_per_sqft',
#        'hotzone_cluster', 'zoning_cluster', 'has_reno', 'has_basement',
#        'is_residential', 'area_mod', 'log_sqft', 'log_sqft_1',
#        'log_sqft_fbsmt', 'total_bath', 'view_west_combo', 'view_east_combo'],
#       dtype='object')

# %% [markdown]
# Lưu tập dữ liệu train và test đã được tiền xử lý ra file .csv vào đường dẫn của Google Colab

# %%
train_data.to_csv(data_folder + 'new_train.csv', index=False)
test_data.to_csv(data_folder + 'new_test.csv', index=False)

# %% [markdown]
# Tải về local các file .csv đã được lưu vào Google Colab ở trên

# %%
files.download(data_folder + 'new_train.csv')
files.download(data_folder + 'new_test.csv')
